# %%
name = 'Danish'
print(name)
# Out:
# Danish

# %%
name1 = "Danish Makhdum"
print(name1)
# Out:
# Danish Makhdum

# %%
2name = """Error test"""
print(2name)
# Out:
#   File "<ipython-input-4-09a1d0ef5538>", line 1
#     2name = """Error test"""
#      ^
# SyntaxError: invalid syntax

# %%
name2 = """Triple quotes"""
print(name2)
# Out:
# Triple quotes

# %%
name3 = """"quad quotes""""
print(name3)
# Out:
#   File "<ipython-input-6-d7d18b3a305c>", line 1
#     name3 = """"quad quotes""""
#                                ^
# SyntaxError: EOL while scanning string literal
